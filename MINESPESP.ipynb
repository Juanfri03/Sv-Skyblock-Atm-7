# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1




version = '1.18.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

elif server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

elif server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /workspaces/codespaces-jupyter/Minecraft-server
# JVM info: Microsoft - 21.0.2 - 21.0.2+13-LTS
# java.net.preferIPv4Stack=true
# Current Time: 05/03/2024 17:21:23
# Host: files.minecraftforge.net [51.79.83.165]
# Host: maven.minecraftforge.net [51.79.83.165]
# Host: libraries.minecraft.net [13.107.253.41, 13.107.226.41]
# Host: launchermeta.mojang.com [13.107.246.41, 13.107.213.41]
# Host: piston-meta.mojang.com [13.107.213.41, 13.107.246.41]
# Host: sessionserver.mojang.com [13.107.253.41, 13.107.226.41]
# Host: authserver.mojang.com [Unknown]
# Target Directory: .
# Data kindly mirrored by CreeperHost at https://www.creeperhost.net/
# Considering minecraft server jar
# Downloading libraries
# Found 0 additional library directories
# Considering library cpw.mods:securejarhandler:1.0.8
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.5
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.5
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.5
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-util:9.5
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-analysis:9.5
#   File exists: Checksum validated.
# Considering library net.minecraftforge:accesstransformers:8.0.4
#   File exists: Checksum validated.
# Considering library org.antlr:antlr4-runtime:4.9.1
#   File exists: Checksum validated.
# Considering library net.minecraftforge:eventbus:5.0.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:forgespi:4.0.15-4.x
#   File exists: Checksum validated.
# Considering library net.minecraftforge:coremods:5.0.1
#   File exists: Checksum validated.
# Considering library cpw.mods:modlauncher:9.1.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:unsafe:0.2.0
#   File exists: Checksum validated.
# Considering library com.electronwill.night-config:core:3.6.4
#   File exists: Checksum validated.
# Considering library com.electronwill.night-config:toml:3.6.4
#   File exists: Checksum validated.
# Considering library org.apache.maven:maven-artifact:3.6.3
#   File exists: Checksum validated.
# Considering library net.jodah:typetools:0.8.3
#   File exists: Checksum validated.
# Considering library net.minecrell:terminalconsoleappender:1.2.0
#   File exists: Checksum validated.
# Considering library org.jline:jline-reader:3.12.1
#   File exists: Checksum validated.
# Considering library org.jline:jline-terminal:3.12.1
#   File exists: Checksum validated.
# Considering library org.spongepowered:mixin:0.8.5
#   File exists: Checksum validated.
# Considering library org.openjdk.nashorn:nashorn-core:15.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarSelector:0.3.19
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarMetadata:0.3.19
#   File exists: Checksum validated.
# Considering library cpw.mods:bootstraplauncher:1.0.0
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarFileSystems:0.3.19
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlloader:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library com.github.jponge:lzma-java:1.3
#   File exists: Checksum validated.
# Considering library com.google.code.findbugs:jsr305:3.0.2
#   File exists: Checksum validated.
# Considering library com.google.code.gson:gson:2.8.7
#   File exists: Checksum validated.
# Considering library com.google.errorprone:error_prone_annotations:2.1.3
#   File exists: Checksum validated.
# Considering library com.google.guava:guava:20.0
#   File exists: Checksum validated.
# Considering library com.google.guava:guava:25.1-jre
#   File exists: Checksum validated.
# Considering library com.google.j2objc:j2objc-annotations:1.1
#   File exists: Checksum validated.
# Considering library com.nothome:javaxdelta:2.0.1
#   File exists: Checksum validated.
# Considering library com.opencsv:opencsv:4.4
#   File exists: Checksum validated.
# Considering library commons-beanutils:commons-beanutils:1.9.3
#   File exists: Checksum validated.
# Considering library commons-collections:commons-collections:3.2.2
#   File exists: Checksum validated.
# Considering library commons-io:commons-io:2.4
#   File exists: Checksum validated.
# Considering library commons-logging:commons-logging:1.2
#   File exists: Checksum validated.
# Considering library de.oceanlabs.mcp:mcp_config:1.18.2-20220404.173914@zip
#   File exists: Checksum validated.
# Considering library de.siegmar:fastcsv:2.0.0
#   File exists: Checksum validated.
# Considering library net.md-5:SpecialSource:1.11.0
#   File exists: Checksum validated.
# Considering library net.minecraftforge:ForgeAutoRenamingTool:0.1.25:all
#   File exists: Checksum validated.
# Considering library net.minecraftforge:binarypatcher:1.0.12
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlcore:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlloader:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:forge:1.18.2-40.2.17:universal
#   File exists: Checksum validated.
# Considering library net.minecraftforge:installertools:1.3.0
#   File exists: Checksum validated.
# Considering library net.minecraftforge:jarsplitter:1.1.4
#   File exists: Checksum validated.
# Considering library net.minecraftforge:javafmllanguage:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:lowcodelanguage:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:mclanguage:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.4.11
#   File exists: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.4.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.4.9
#   File exists: Checksum validated.
# Considering library net.sf.jopt-simple:jopt-simple:5.0.4
#   File exists: Checksum validated.
# Considering library net.sf.jopt-simple:jopt-simple:6.0-alpha-3
#   File exists: Checksum validated.
# Considering library org.apache.commons:commons-collections4:4.2
#   File exists: Checksum validated.
# Considering library org.apache.commons:commons-lang3:3.8.1
#   File exists: Checksum validated.
# Considering library org.apache.commons:commons-text:1.3
#   File exists: Checksum validated.
# Considering library org.checkerframework:checker-qual:2.0.0
#   File exists: Checksum validated.
# Considering library org.codehaus.mojo:animal-sniffer-annotations:1.14
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-analysis:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-analysis:9.3
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.3
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.3
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.3
#   File exists: Checksum validated.
# Considering library trove:trove:1.0.2
#   File exists: Checksum validated.
# Created Temporary Directory: /tmp/forge_installer4921751713918329420
#   Extracting: /data/server.lzma
# Building Processors
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, EXTRACT_FILES, --archive, /workspaces/codespaces-jupyter/Minecraft-server/forge.jar, --from, data/run.sh, --to, /workspaces/codespaces-jupyter/Minecraft-server/./run.sh, --exec, /workspaces/codespaces-jupyter/Minecraft-server/./run.sh, --from, data/run.bat, --to, /workspaces/codespaces-jupyter/Minecraft-server/./run.bat, --from, data/user_jvm_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt, --optional, /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt, --from, data/win_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.18.2-40.2.17/win_args.txt, --from, data/unix_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.18.2-40.2.17/unix_args.txt
# Task: EXTRACT_FILES
# Archive: /workspaces/codespaces-jupyter/Minecraft-server/forge.jar
# Extract: data/run.sh
#          /workspaces/codespaces-jupyter/Minecraft-server/./run.sh
# Extract: data/run.bat
#          /workspaces/codespaces-jupyter/Minecraft-server/./run.bat
# Extract: data/user_jvm_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt
# Extract: data/win_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.18.2-40.2.17/win_args.txt
# Extract: data/unix_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.18.2-40.2.17/unix_args.txt
# Exec:    /workspaces/codespaces-jupyter/Minecraft-server/./run.sh
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, BUNDLER_EXTRACT, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2/server-1.18.2.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/, --libraries
# Task: BUNDLER_EXTRACT
# Input:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2/server-1.18.2.jar
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries
# All:     false
# JarOnly: false
# Libs:    true
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, BUNDLER_EXTRACT, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2/server-1.18.2.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-unpacked.jar, --jar-only
# Task: BUNDLER_EXTRACT
# Input:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2/server-1.18.2.jar
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-unpacked.jar
# All:     false
# JarOnly: true
# Libs:    false
# File already exists, and hash verified
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, MCP_DATA, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914.zip, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings.txt, --key, mappings
# Task: MCP_DATA
# Input:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914.zip
# Output: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings.txt
# Key:    mappings
# Extracting: config/joined.tsrg
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, DOWNLOAD_MOJMAPS, --version, 1.18.2, --side, server, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-mappings.txt
# Task: DOWNLOAD_MOJMAPS
# MC Version: 1.18.2
# Side:       server
# Output:     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-mappings.txt
# Downloaded Mojang mappings for 1.18.2
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, MERGE_MAPPING, --left, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings.txt, --right, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-mappings.txt, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings-merged.txt, --classes, --reverse-right
# Task: MERGE_MAPPING
# Left:    /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings.txt
#          Reversed=false
#          null
# Right:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-mappings.txt
#          Reversed=true
#          null
# Classes: true
# Fields:  false
# Methods: false
# Params:  false
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings-merged.txt
# ===============================================================================
#   Cache:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-slim.jar Validated: 92c652fa6f3574b07d31ab22696c2dbdcd0c4c04
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-extra.jar Validated: 4f1ba0161f6d78345feaf2f469abf809ee18cd9f
#   Cache Hit!
# ===============================================================================
#   MainClass: net.minecraftforge.fart.Main
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/ForgeAutoRenamingTool/0.1.25/ForgeAutoRenamingTool-0.1.25-all.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.2/asm-commons-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.2/asm-analysis-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.2/asm-tree-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.2/asm-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.9/srgutils-0.4.9.jar
#   Args: --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-slim.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar, --names, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings-merged.txt, --ann-fix, --ids-fix, --src-fix, --record-fix
# Forge Auto Renaming Tool v0.1.25
# log: null
# input: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-slim.jar
# output: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar
# threads: 4
# Names: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings-merged.txt(reversed: false)
# Fix Annotations: true
# Fix Records: true
# Fix Identifiers: ALL
# Fix SourceFile: JAVA
# Fix Line Numbers: false
# Strip codesigning signatures: false
# Adding Libraries to Inheritance
# Reading Input: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-slim.jar
# Adding input to inheritence map
# Processing entries
# Cant Find Class: org/slf4j/Logger
# Cant Find Class: javax/annotation/ParametersAreNonnullByDefault
# Cant Find Class: org/apache/commons/lang3/exception/ExceptionUtils
# Cant Find Class: com/google/common/base/MoreObjects
# Cant Find Class: javax/annotation/Nullable
# Cant Find Class: com/mojang/authlib/GameProfile
# Cant Find Class: com/google/common/collect/Lists
# Cant Find Class: com/mojang/brigadier/Message
# Cant Find Class: com/google/common/collect/Sets
# Cant Find Class: com/google/common/collect/Maps
# Cant Find Class: com/mojang/brigadier/exceptions/CommandSyntaxException
# Cant Find Class: org/apache/commons/io/IOUtils
# Cant Find Class: com/mojang/serialization/Keyable
# Cant Find Class: com/mojang/datafixers/util/Pair
# Cant Find Class: com/google/common/collect/ImmutableList
# Cant Find Class: com/mojang/logging/LogUtils
# Cant Find Class: com/google/common/escape/Escapers$Builder
# Cant Find Class: com/google/common/escape/Escapers
# Cant Find Class: com/google/common/escape/Escaper
# Cant Find Class: com/mojang/brigadier/arguments/ArgumentType
# Cant Find Class: com/mojang/brigadier/StringReader
# Cant Find Class: com/mojang/brigadier/exceptions/SimpleCommandExceptionType
# Cant Find Class: com/mojang/brigadier/exceptions/CommandExceptionType
# Cant Find Class: com/mojang/brigadier/context/CommandContext
# Cant Find Class: com/mojang/brigadier/suggestion/SuggestionsBuilder
# Cant Find Class: com/mojang/brigadier/CommandDispatcher
# Cant Find Class: com/mojang/brigadier/builder/LiteralArgumentBuilder
# Cant Find Class: com/mojang/brigadier/Command
# Cant Find Class: com/mojang/brigadier/builder/ArgumentBuilder
# Cant Find Class: com/mojang/brigadier/arguments/BoolArgumentType
# Cant Find Class: com/mojang/brigadier/builder/RequiredArgumentBuilder
# Cant Find Class: com/mojang/brigadier/arguments/IntegerArgumentType
# Cant Find Class: com/mojang/brigadier/arguments/StringArgumentType
# Cant Find Class: com/mojang/brigadier/tree/LiteralCommandNode
# Cant Find Class: org/apache/commons/lang3/mutable/MutableInt
# Cant Find Class: com/google/common/collect/Iterables
# Cant Find Class: com/google/common/collect/Streams
# Cant Find Class: com/mojang/brigadier/suggestion/Suggestions
# Cant Find Class: com/mojang/datafixers/DataFixer
# Cant Find Class: com/mojang/authlib/minecraft/MinecraftSessionService
# Cant Find Class: com/mojang/authlib/GameProfileRepository
# Cant Find Class: com/google/common/base/Stopwatch
# Cant Find Class: com/mojang/serialization/Lifecycle
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectSet
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectIterator
# Cant Find Class: it/unimi/dsi/fastutil/Hash$Strategy
# Cant Find Class: it/unimi/dsi/fastutil/Hash
# Cant Find Class: javax/annotation/Nonnull
# Cant Find Class: com/google/common/base/Ticker
# Cant Find Class: javax/annotation/meta/TypeQualifierDefault
# Cant Find Class: com/mojang/datafixers/DSL$TypeReference
# Cant Find Class: com/mojang/datafixers/DSL
# Cant Find Class: com/google/common/util/concurrent/MoreExecutors
# Cant Find Class: com/google/common/util/concurrent/ListeningExecutorService
# Cant Find Class: com/google/gson/JsonDeserializer
# Cant Find Class: com/google/gson/JsonSerializer
# Cant Find Class: com/mojang/datafixers/types/Type
# Cant Find Class: com/mojang/bridge/game/GameVersion
# Cant Find Class: com/mojang/datafixers/DataFixUtils
# Cant Find Class: com/mojang/datafixers/schemas/Schema
# Cant Find Class: com/google/gson/JsonObject
# Cant Find Class: com/google/gson/JsonElement
# Cant Find Class: org/apache/commons/io/FilenameUtils
# Cant Find Class: com/google/gson/JsonSyntaxException
# Cant Find Class: com/google/gson/JsonParseException
# Cant Find Class: io/netty/buffer/ByteBuf
# Cant Find Class: com/google/gson/JsonNull
# Cant Find Class: com/google/gson/JsonArray
# Cant Find Class: com/google/common/collect/Iterators
# Cant Find Class: com/google/gson/JsonPrimitive
# Cant Find Class: com/google/common/collect/ImmutableMap
# Cant Find Class: com/google/gson/JsonSerializationContext
# Cant Find Class: com/mojang/serialization/DataResult
# Cant Find Class: com/mojang/brigadier/ImmutableStringReader
# Cant Find Class: com/mojang/brigadier/exceptions/BuiltInExceptionProvider
# Cant Find Class: com/mojang/brigadier/exceptions/DynamicCommandExceptionType
# Cant Find Class: com/google/gson/JsonDeserializationContext
# Cant Find Class: com/google/common/collect/ImmutableSet
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArrayList
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanOpenHashMap
# Cant Find Class: com/google/common/base/Joiner
# Cant Find Class: com/google/gson/Gson
# Cant Find Class: com/google/gson/GsonBuilder
# Cant Find Class: com/google/common/collect/Multimap
# Cant Find Class: com/google/common/collect/ImmutableSet$Builder
# Cant Find Class: com/mojang/serialization/Codec
# Cant Find Class: com/mojang/serialization/JsonOps
# Cant Find Class: com/mojang/serialization/DynamicOps
# Cant Find Class: org/apache/commons/lang3/ArrayUtils
# Cant Find Class: com/mojang/brigadier/ParseResults
# Cant Find Class: com/mojang/brigadier/context/CommandContextBuilder
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntOpenHashMap
# Cant Find Class: com/mojang/brigadier/tree/CommandNode
# Cant Find Class: com/mojang/brigadier/AmbiguityConsumer
# Cant Find Class: com/mojang/brigadier/ResultConsumer
# Cant Find Class: com/mojang/brigadier/tree/RootCommandNode
# Cant Find Class: com/mojang/brigadier/suggestion/SuggestionProvider
# Cant Find Class: com/mojang/brigadier/context/StringRange
# Cant Find Class: com/mojang/datafixers/util/Either
# Cant Find Class: org/apache/commons/lang3/mutable/MutableBoolean
# Cant Find Class: com/mojang/brigadier/exceptions/Dynamic2CommandExceptionType$Function
# Cant Find Class: com/mojang/brigadier/exceptions/Dynamic2CommandExceptionType
# Cant Find Class: com/google/common/primitives/Doubles
# Cant Find Class: com/mojang/brigadier/exceptions/Dynamic3CommandExceptionType$Function
# Cant Find Class: com/mojang/brigadier/exceptions/Dynamic3CommandExceptionType
# Cant Find Class: com/google/common/collect/UnmodifiableIterator
# Cant Find Class: com/mojang/brigadier/arguments/LongArgumentType
# Cant Find Class: com/mojang/brigadier/arguments/StringArgumentType$StringType
# Cant Find Class: com/mojang/brigadier/arguments/FloatArgumentType
# Cant Find Class: com/mojang/brigadier/arguments/DoubleArgumentType
# Cant Find Class: com/mojang/brigadier/tree/ArgumentCommandNode
# Cant Find Class: com/google/common/base/Strings
# Cant Find Class: com/google/common/collect/AbstractIterator
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2ObjectOpenHashMap
# Cant Find Class: com/mojang/serialization/codecs/RecordCodecBuilder$Instance
# Cant Find Class: com/mojang/serialization/codecs/RecordCodecBuilder
# Cant Find Class: com/mojang/datafixers/Products$P1
# Cant Find Class: com/mojang/datafixers/Products
# Cant Find Class: com/mojang/datafixers/Products$P3
# Cant Find Class: com/mojang/datafixers/Products$P2
# Cant Find Class: com/mojang/datafixers/kinds/App
# Cant Find Class: com/mojang/serialization/MapCodec
# Cant Find Class: com/mojang/datafixers/kinds/Applicative
# Cant Find Class: com/mojang/serialization/codecs/PrimitiveCodec
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectOpenHashMap
# Cant Find Class: com/mojang/datafixers/util/Function3
# Cant Find Class: javax/annotation/concurrent/Immutable
# Cant Find Class: com/google/common/base/MoreObjects$ToStringHelper
# Cant Find Class: org/apache/commons/lang3/Validate
# Cant Find Class: com/mojang/serialization/Decoder
# Cant Find Class: com/google/common/collect/ImmutableMap$Builder
# Cant Find Class: com/mojang/serialization/DataResult$PartialResult
# Cant Find Class: com/mojang/serialization/codecs/UnboundedMapCodec
# Cant Find Class: com/mojang/serialization/Encoder
# Cant Find Class: com/mojang/serialization/Dynamic
# Cant Find Class: com/google/common/base/Supplier
# Cant Find Class: com/google/common/base/Suppliers
# Cant Find Class: org/jetbrains/annotations/Nullable
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongConsumer
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntOpenCustomHashMap
# Cant Find Class: com/google/common/base/Predicate
# Cant Find Class: com/google/common/collect/ImmutableList$Builder
# Cant Find Class: com/google/common/collect/Sets$SetView
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectList
# Cant Find Class: com/google/common/base/Function
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectOpenHashMap
# Cant Find Class: org/jetbrains/annotations/NotNull
# Cant Find Class: oshi/hardware/CentralProcessor$ProcessorIdentifier
# Cant Find Class: oshi/hardware/CentralProcessor
# Found extra RuntimeVisibleParameterAnnotations entries in <init>(Ljava/lang/String;ILjava/lang/String;CILjava/lang/Integer;)V in net/minecraft/ChatFormatting: removing 2
# Found extra RuntimeVisibleParameterAnnotations entries in <init>(Ljava/lang/String;ILjava/lang/String;CZILjava/lang/Integer;)V in net/minecraft/ChatFormatting: removing 2
# Cant Find Class: oshi/SystemInfo
# Cant Find Class: oshi/hardware/HardwareAbstractionLayer
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMaps
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMap$Entry
# Cant Find Class: org/apache/commons/io/FileUtils
# Cant Find Class: com/google/gson/stream/JsonReader
# Cant Find Class: oshi/hardware/PhysicalMemory
# Cant Find Class: oshi/hardware/VirtualMemory
# Cant Find Class: oshi/hardware/GlobalMemory
# Cant Find Class: oshi/hardware/GraphicsCard
# Cant Find Class: com/google/gson/internal/Streams
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntList
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntArrayList
# Cant Find Class: com/google/common/collect/ComparisonChain
# Cant Find Class: com/google/common/collect/HashBasedTable
# Cant Find Class: com/google/common/collect/Table
# Cant Find Class: org/apache/commons/lang3/StringUtils
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2DoubleMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2DoubleArrayMap
# Cant Find Class: com/google/common/base/Objects
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectAVLTreeMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectSortedMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectCollection
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntAVLTreeSet
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntCollection
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntIterator
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2IntMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntListIterator
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2IntOpenHashMap
# Cant Find Class: com/google/common/annotations/VisibleForTesting
# Cant Find Class: com/google/common/base/Predicates
# Found extra RuntimeVisibleParameterAnnotations entries in <init>(Lnet/minecraft/world/entity/animal/Fox;Ljava/lang/Class;ZZLjava/util/function/Predicate;)V in net/minecraft/world/entity/animal/Fox$DefendTrustedTargetGoal: removing 1
# Cant Find Class: org/apache/commons/lang3/tuple/Pair
# Cant Find Class: io/netty/channel/SimpleChannelInboundHandler
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntOpenHashSet
# Cant Find Class: org/apache/commons/lang3/mutable/MutableObject
# Cant Find Class: com/mojang/serialization/MapLike
# Cant Find Class: com/mojang/serialization/RecordBuilder
# Cant Find Class: io/netty/util/internal/ThreadLocalRandom
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2ObjectArrayMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArraySet
# Cant Find Class: com/mojang/datafixers/Products$P4
# Cant Find Class: com/mojang/datafixers/util/Function4
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongOpenHashSet
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectOpenHashSet
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ByteMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ByteOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectFunction
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongMap
# Cant Find Class: com/mojang/serialization/OptionalDynamic
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectFunction
# Cant Find Class: com/mojang/serialization/DataResult$Instance
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntBinaryOperator
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntSet
# Cant Find Class: com/mojang/serialization/DynamicLike
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectListIterator
# Cant Find Class: com/google/common/primitives/UnsignedLong
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongIterator
# Cant Find Class: com/mojang/datafixers/Products$P8
# Cant Find Class: com/mojang/datafixers/util/Function8
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2BooleanMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2BooleanFunction
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2BooleanOpenHashMap
# Cant Find Class: com/mojang/datafixers/Products$P6
# Cant Find Class: com/mojang/datafixers/util/Function6
# Cant Find Class: com/google/common/collect/Queues
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArrays
# Cant Find Class: com/mojang/datafixers/Products$P5
# Cant Find Class: com/mojang/datafixers/util/Function5
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongArrayList
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongList
# Cant Find Class: com/mojang/serialization/codecs/RecordCodecBuilder$Mu
# Cant Find Class: com/mojang/datafixers/Products$P7
# Cant Find Class: com/mojang/datafixers/util/Function7
# Cant Find Class: com/google/common/cache/CacheLoader
# Cant Find Class: com/google/common/cache/LoadingCache
# Cant Find Class: com/google/common/cache/CacheBuilder
# Cant Find Class: com/mojang/serialization/codecs/SimpleMapCodec
# Cant Find Class: com/mojang/datafixers/Products$P13
# Cant Find Class: com/mojang/datafixers/util/Function13
# Cant Find Class: com/mojang/datafixers/Products$P9
# Cant Find Class: com/mojang/datafixers/util/Function9
# Cant Find Class: com/mojang/datafixers/Products$P11
# Cant Find Class: com/mojang/datafixers/util/Function11
# Cant Find Class: com/mojang/datafixers/Products$P10
# Cant Find Class: com/mojang/datafixers/util/Function10
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleList
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleArrayList
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleListIterator
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntRBTreeSet
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntSortedSet
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntBidirectionalIterator
# Cant Find Class: it/unimi/dsi/fastutil/doubles/Double2DoubleFunction
# Cant Find Class: com/mojang/datafixers/Products$P15
# Cant Find Class: com/mojang/datafixers/util/Function15
# Cant Find Class: org/apache/commons/lang3/mutable/MutableDouble
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2IntMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2IntOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2IntFunction
# Cant Find Class: com/google/common/hash/HashFunction
# Cant Find Class: com/google/common/base/Charsets
# Cant Find Class: com/google/common/hash/HashCode
# Cant Find Class: com/google/common/primitives/Longs
# Cant Find Class: com/google/common/hash/Hashing
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongSortedSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongAVLTreeSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongBidirectionalIterator
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectMaps
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectIterable
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectLinkedOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMaps
# Cant Find Class: com/google/common/io/Files
# Cant Find Class: com/google/common/io/ByteSource
# Cant Find Class: com/google/common/collect/HashMultimap
# Cant Find Class: com/google/common/collect/ImmutableMultimap
# Cant Find Class: com/google/common/collect/BiMap
# Cant Find Class: com/google/common/collect/HashBiMap
# Cant Find Class: com/google/gson/TypeAdapter
# Cant Find Class: com/google/gson/stream/JsonWriter
# Cant Find Class: org/slf4j/Marker
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongLinkedOpenHashSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongCollection
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongLinkedOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/HashCommon
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2ByteLinkedOpenHashMap
# Cant Find Class: com/google/common/base/Preconditions
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2BooleanMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2BooleanFunction
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2BooleanOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/floats/Float2FloatFunction
# Cant Find Class: com/google/common/collect/ImmutableSortedMap
# Cant Find Class: com/google/common/collect/ArrayTable
# Cant Find Class: com/google/common/collect/AbstractTable
# Cant Find Class: com/mojang/serialization/MapEncoder
# Cant Find Class: com/mojang/serialization/MapDecoder
# ...
#   Patching net/minecraft/client/renderer/Sheets$1 1/1
#   Patching net/minecraft/client/resources/language/LanguageInfo 1/1
#   Patching net/minecraft/client/gui/screens/recipebook/RecipeBookPage 1/1
#   Patching net/minecraft/client/RecipeBookCategories$1 1/1
#   Patching net/minecraft/client/renderer/texture/TextureManager 1/1
#   Patching net/minecraft/client/gui/screens/inventory/AbstractContainerScreen 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$Cache 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/ServerSelectionList$OnlineServerEntry 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$BlendState 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat$Mode 1/1
#   Patching net/minecraft/client/renderer/texture/TextureAtlas$Preparations 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransforms$Deserializer 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$DestFactor 1/1
#   Patching net/minecraft/client/gui/components/AbstractSelectionList$Entry 1/1
#   Patching net/minecraft/client/renderer/ShaderInstance$1 1/1
#   Patching net/minecraft/client/renderer/blockentity/BlockEntityRenderers 1/1
#   Patching net/minecraft/client/resources/model/SimpleBakedModel$Builder 1/1
#   Patching net/minecraft/client/gui/screens/inventory/EnchantmentScreen 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionScreen$1 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/CreateWorldScreen$OperationFailedException 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer$RenderInfoMap 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsScreen 1/1
#   Patching net/minecraft/client/multiplayer/ServerData$ServerPackStatus 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$Entry 1/1
#   Patching net/minecraft/client/renderer/blockentity/PistonHeadRenderer 1/1
#   Patching net/minecraft/client/Minecraft$1 1/1
#   Patching net/minecraft/client/multiplayer/ClientLevel$1 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/ServerSelectionList$LANHeader 1/1
#   Patching net/minecraft/client/KeyMapping 1/1
#   Patching net/minecraft/client/gui/screens/ConnectScreen$1 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$3 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$4 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$SourceFactor 1/1
#   Patching net/minecraft/client/User 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen$SlotWrapper 1/1
#   Patching net/minecraft/client/resources/language/ClientLanguage 1/1
#   Patching net/minecraft/client/KeyboardHandler$1 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$Cache$1 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$Cache$2 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/ServerSelectionList$NetworkServerEntry 1/1
#   Patching net/minecraft/client/renderer/RenderType 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$CompiledChunk$1 1/1
#   Patching net/minecraft/client/renderer/entity/ItemEntityRenderer 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$SpanFacing 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$Deserializer 1/1
#   Patching net/minecraft/client/renderer/entity/EntityRenderer 1/1
#   Patching net/minecraft/client/multiplayer/ClientChunkCache$Storage 1/1
#   Patching net/minecraft/client/gui/components/DebugScreenOverlay 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$1 1/1
#   Patching net/minecraft/client/renderer/entity/LivingEntityRenderer$1 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$2 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$1 1/1
#   Patching net/minecraft/client/multiplayer/ClientLevel$EntityCallbacks 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$2 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldPreset 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer$RenderChunkInfo 1/1
#   Patching net/minecraft/client/server/IntegratedServer 1/1
#   Patching net/minecraft/client/resources/model/MultiPartBakedModel$Builder 1/1
#   Patching net/minecraft/client/renderer/FogRenderer 1/1
#   Patching net/minecraft/client/renderer/block/LiquidBlockRenderer$1 1/1
#   Patching net/minecraft/client/renderer/block/BlockRenderDispatcher 1/1
#   Patching net/minecraft/client/resources/model/ModelManager 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$Span 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer 1/1
#   Patching net/minecraft/client/renderer/block/LiquidBlockRenderer 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$SnowballProvider 1/1
#   Patching com/mojang/blaze3d/vertex/VertexMultiConsumer 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ScissorState 1/1
#   Patching net/minecraft/client/renderer/entity/LivingEntityRenderer 1/1
#   Patching net/minecraft/client/multiplayer/ClientChunkCache 1/1
#   Patching net/minecraft/client/renderer/PostChain 1/1
#   Patching net/minecraft/client/renderer/Sheets 1/1
#   Patching net/minecraft/client/renderer/entity/player/PlayerRenderer 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat$IndexType 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$LoopException 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$SizeInfo 1/1
#   Patching net/minecraft/client/renderer/RenderType$CompositeState$CompositeStateBuilder 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer$HandRenderSelection 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$TextureState 1/1
#   Patching net/minecraft/client/renderer/texture/TextureAtlasSprite$AnimatedTexture 1/1
#   Patching net/minecraft/client/ClientBrandRetriever 1/1
#   Patching net/minecraft/client/gui/MapRenderer$MapInstance 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemOverrides 1/1
#   Patching net/minecraft/client/gui/Gui$HeartType 1/1
#   Patching net/minecraft/client/renderer/entity/layers/ElytraLayer 1/1
#   Patching net/minecraft/client/gui/screens/Screen 1/1
#   Patching com/mojang/blaze3d/vertex/VertexMultiConsumer$Multiple 1/1
#   Patching net/minecraft/client/particle/TerrainParticle 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage$ClearState 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder$DrawState 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ColorMask 1/1
#   Patching com/mojang/blaze3d/platform/Window 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransform 1/1
#   Patching net/minecraft/client/gui/components/BossHealthOverlay 1/1
#   Patching net/minecraft/client/renderer/ItemModelShaper 1/1
#   Patching net/minecraft/client/player/RemotePlayer 1/1
#   Patching net/minecraft/client/main/Main 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$ResortTransparencyTask 1/1
#   Patching net/minecraft/client/gui/screens/Screen$NarratableSearchResult 1/1
#   Patching net/minecraft/client/resources/model/BakedModel 1/1
#   Patching net/minecraft/world/level/biome/BiomeSpecialEffects$GrassColorModifier$ColorModifier 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$OverworldEffects 1/1
#   Patching net/minecraft/client/gui/screens/TitleScreen$1 1/1
#   Patching net/minecraft/client/gui/components/AbstractSelectionList$TrackedList 1/1
#   Patching net/minecraft/client/renderer/EffectInstance 1/1
#   Patching net/minecraft/client/renderer/SpriteCoordinateExpander 1/1
#   Patching net/minecraft/Util$3 1/1
#   Patching net/minecraft/client/multiplayer/ClientPacketListener 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$EndEffects 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementsScreen 1/1
#   Patching com/mojang/blaze3d/pipeline/RenderTarget 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldSelectionList$WorldListEntry 1/1
#   Patching net/minecraft/client/renderer/OutlineBufferSource 1/1
#   Patching net/minecraft/client/resources/model/ModelState 1/1
#   Patching net/minecraft/client/server/LanServerDetection$LanServerDetector 1/1
#   Patching net/minecraft/client/sounds/SoundEngine 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$DepthState 1/1
#   Patching net/minecraft/client/multiplayer/ServerData 1/1
#   Patching net/minecraft/client/renderer/texture/TextureAtlas 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$1 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer$1 1/1
#   Patching net/minecraft/client/gui/screens/LoadingOverlay 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$SlimeProvider 1/1
#   Patching net/minecraft/client/renderer/entity/ItemFrameRenderer 1/1
#   Patching net/minecraft/client/renderer/FogRenderer$FogMode 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldSelectionList 1/1
#   Patching net/minecraft/client/gui/screens/inventory/LoomScreen 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$Viewport 1/1
#   Patching net/minecraft/client/renderer/item/ItemProperties$CompassWobble 1/1
#   Patching net/minecraft/client/resources/model/WeightedBakedModel 1/1
#   Patching net/minecraft/client/renderer/ShaderInstance 1/1
#   Patching net/minecraft/client/Minecraft 1/1
#   Patching net/minecraft/client/ToggleKeyMapping 1/1
#   Patching net/minecraft/client/renderer/RenderType$CompositeRenderType 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$ChunkTaskResult 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransforms$1 1/1
#   Patching net/minecraft/client/gui/screens/ConnectScreen 1/1
#   Patching net/minecraft/client/renderer/blockentity/SkullBlockRenderer 1/1
#   Patching net/minecraft/client/server/LanServerDetection$LanServerList 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$AmbientVertexRemap 1/1
#   Patching net/minecraft/client/particle/ParticleEngine 1/1
#   Patching net/minecraft/client/gui/screens/DeathScreen 1/1
#   Patching net/minecraft/client/renderer/block/model/BakedQuad 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ColorLogicState 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTabType 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$EntryBase 1/1
#   Patching net/minecraft/client/renderer/entity/EntityRenderDispatcher 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemOverrides$PropertyMatcher 1/1
#   Patching net/minecraft/world/item/Items$1 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$Provider 1/1
#   Patching net/minecraft/client/gui/components/DebugScreenOverlay$1 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$GuiLight 1/1
#   Patching net/minecraft/client/gui/screens/inventory/tooltip/ClientTooltipComponent 1/1
#   Patching net/minecraft/client/renderer/texture/Stitcher$Holder 1/1
#   Patching net/minecraft/client/Screenshot 1/1
#   Patching com/mojang/blaze3d/vertex/SheetedDecalTextureGenerator 1/1
#   Patching net/minecraft/client/User$Type 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldPreset$PresetEditor 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldGenSettingsComponent 1/1
#   Patching com/mojang/realmsclient/gui/screens/RealmsGenericErrorScreen 1/1
#   Patching net/minecraft/client/gui/screens/OptionsScreen 1/1
#   Patching net/minecraft/client/RecipeBookCategories 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat$1 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransforms$TransformType 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer$RenderChunkStorage 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$UnselectedPackEntry 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$1 1/1
#   Patching net/minecraft/client/renderer/block/model/FaceBakery 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$LogicOp 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen 1/1
#   Patching net/minecraft/client/resources/language/I18n 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTabType$1 1/1
#   Patching net/minecraft/client/gui/components/AbstractWidget 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$SkyType 1/1
#   Patching net/minecraft/client/gui/screens/LoadingOverlay$LogoTexture 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/JoinMultiplayerScreen 1/1
#   Patching net/minecraft/client/renderer/block/BlockRenderDispatcher$1 1/1
#   Patching net/minecraft/client/particle/ParticleEngine$SpriteParticleRegistration 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList$CategoryEntry 1/1
#   Patching net/minecraft/client/player/AbstractClientPlayer 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTab 1/1
#   Patching net/minecraft/client/KeyboardHandler 1/1
#   Patching net/minecraft/client/renderer/entity/BoatRenderer 1/1
#   Patching net/minecraft/client/gui/screens/MenuScreens$ScreenConstructor 1/1
#   Patching net/minecraft/client/multiplayer/ClientLevel$ClientLevelData 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$ChunkCompileTask 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen$CustomCreativeSlot 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$2$1 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$AmbientOcclusionFace 1/1
#   Patching net/minecraft/client/multiplayer/ClientHandshakePacketListenerImpl 1/1
#   Patching net/minecraft/client/multiplayer/ClientPacketListener$1 1/1
#   Patching net/minecraft/client/particle/ParticleEngine$MutableSpriteSet 1/1
#   Patching net/minecraft/client/color/item/ItemColors 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList$CategoryEntry$1 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransform$Deserializer 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder$SortState 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$SelectedPackEntry 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$RebuildTask 1/1
#   Patching net/minecraft/client/renderer/texture/MipmapGenerator 1/1
#   Patching net/minecraft/client/renderer/ScreenEffectRenderer 1/1
#   Patching net/minecraft/client/gui/screens/MenuScreens 1/1
#   Patching net/minecraft/client/gui/screens/TitleScreen 1/1
#   Patching net/minecraft/client/main/Main$2 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/CreateWorldScreen$SelectedGameMode 1/1
#   Patching net/minecraft/client/main/Main$1 1/1
#   Patching net/minecraft/client/server/LanServerPinger 1/1
#   Patching net/minecraft/client/main/Main$3 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle 1/1
#   Patching net/minecraft/client/gui/screens/TitleScreen$Warning32Bit 1/1
#   Patching net/minecraft/client/resources/model/SimpleBakedModel 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager 1/1
#   Patching net/minecraft/client/multiplayer/MultiPlayerGameMode 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen$ItemPickerMenu 1/1
#   Patching net/minecraft/client/renderer/entity/ItemRenderer 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage$SetupState 1/1
# The server installed successfully
# You can delete this installer file now if you wish
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def ejecutar_comando(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

# Purga versiones anteriores de OpenJDK
ejecutar_comando('sudo apt-get purge openjdk* -y')

# Instala OpenJDK 17
ejecutar_comando('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dHlXuFqHYJB3s3BUHrZVUr4IOD_4njXhSYD3JNEA4zQTqmjJ" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'sa' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui

print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
    
    if forgepreversion:
    
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
    
    else:
    
        print("No se encontraron archivos en el directorio Forge.")
    
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o purpur

else:
    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui   

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar.log  packmenu		    user_jvm_args.txt
# banned-players.json  kubejs	    patchouli_books	    usercache.json
# colabconfig.json     libraries	    rhino.local.properties  usernamecache.json
# config		     local	    run.bat		    whitelist.json
# defaultconfigs	     logs	    run.sh		    world
# eula.txt	     mods	    server.properties
# forge.jar	     ops.json	    skyblock_exports
# OpenJDK 17 instalado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# t=2024-03-05T21:10:09+0000 lvl=warn msg="can't bind default web address, trying alternatives" obj=web addr=127.0.0.1:4040
# La IP de tu servidor es 0.tcp.sa.ngrok.io:13662
# Iniciando servidor...
# La versión de Forge es: 1.18.2-40.2.17
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.18.2-40.2.17/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [21:10:14] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.17, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914]
# [21:10:14] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 21.0.2 by Microsoft
# [21:10:17] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2314!/ Service=ModLauncher Env=SERVER
# [21:10:19] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.18.2-40.2.17/fmlcore-1.18.2-40.2.17.jar is missing mods.toml file
# [21:10:19] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.18.2-40.2.17/javafmllanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [21:10:19] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.18.2-40.2.17/lowcodelanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [21:10:19] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.18.2-40.2.17/mclanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [21:10:19] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 4 dependencies adding them to mods collection
# [21:10:43] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [21:10:43] [main/ERROR] [mixin/]: Mixin config tklib.mixin.json does not specify "minVersion" property
# [21:10:43] [main/ERROR] [mixin/]: Mixin config myrtrees-common.mixins.json does not specify "minVersion" property
# [21:10:43] [main/ERROR] [mixin/]: Mixin config supercircuitmaker.mixin.json does not specify "minVersion" property
# [21:10:43] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [com.thevortex.allthetweaks.mixin.MixinConnector]
# [21:10:43] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [com.leobeliik.extremesoundmuffler.MixinConnector]
# [21:10:43] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [21:10:43] [main/WARN] [mixin/]: Reference map 'compactmachines.refmap.json' for compactmachines.mixin.json could not be read. If this is a development environment you can ignore this message
# [21:10:44] [main/WARN] [mixin/]: Reference map 'myrtrees-common-refmap.json' for myrtrees-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [21:10:44] [main/WARN] [mixin/]: Reference map 'supercircuitmaker.refmap.json' for supercircuitmaker.mixin.json could not be read. If this is a development environment you can ignore this message
# [21:10:44] [main/WARN] [mixin/]: Reference map 'insanelib.refmap.json' for insanelib.mixins.json could not be read. If this is a development environment you can ignore this message
# [21:10:44] [main/WARN] [mixin/]: Reference map 'bloodmagic.refmap.json' for bloodmagic.mixins.json could not be read. If this is a development environment you can ignore this message
# [21:10:44] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [21:10:45] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Patching FishingHook#catchingFish
# [21:10:45] [main/WARN] [mixin/]: Error loading class: mezz/jei/transfer/RecipeTransferUtil (java.lang.ClassNotFoundException: mezz.jei.transfer.RecipeTransferUtil)
# [21:10:45] [main/WARN] [mixin/]: @Mixin target mezz.jei.transfer.RecipeTransferUtil was not found polymorph_integrations.mixins.json:jei.MixinRecipeTransferUtil
# [21:10:45] [main/WARN] [mixin/]: Error loading class: net/dries007/tfc/common/items/TorchItem (java.lang.ClassNotFoundException: net.dries007.tfc.common.items.TorchItem)
# [21:10:45] [main/WARN] [mixin/]: @Mixin target net.dries007.tfc.common.items.TorchItem was not found allthetweaks.mixins.json:TFCTorch
# [21:10:45] [main/WARN] [mixin/]: Error loading class: com/eerussianguy/firmalife/common/items/JarsBlockItem (java.lang.ClassNotFoundException: com.eerussianguy.firmalife.common.items.JarsBlockItem)
# [21:10:45] [main/WARN] [mixin/]: @Mixin target com.eerussianguy.firmalife.common.items.JarsBlockItem was not found allthetweaks.mixins.json:BreathMint
# [21:10:45] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/screens/inventory/AbstractContainerScreen for invalid dist DEDICATED_SERVER
# [21:10:45] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/inventory/AbstractContainerScreen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/inventory/AbstractContainerScreen for invalid dist DEDICATED_SERVER)
# [21:10:45] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.inventory.AbstractContainerScreen was not found findme-common.mixins.json:MixinSlotRenderer
# [21:10:45] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/particle/ParticleEngine for invalid dist DEDICATED_SERVER
# [21:10:45] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/particle/ParticleEngine (java.lang.RuntimeException: Attempted to load class net/minecraft/client/particle/ParticleEngine for invalid dist DEDICATED_SERVER)
# [21:10:45] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.particle.ParticleEngine was not found findme-common.mixins.json:ParticleEngineAccessor
# [21:10:47] [main/INFO] [co.un.de.LoggerHacks/]: !!! SOME LOGGERS HAVE MOVED TO THE DEBUG FILE (Please Include them in your bug reports) !!!
# [21:10:50] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [21:10:53] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Patching FishingHook#catchingFish
# [21:10:55] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/EnchantedBookItem
# [21:10:56] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [21:10:56] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [21:11:10] [modloading-worker-0/INFO] [ne.pe.no.NoVillagerDeathMessages/]: Registering mod: novillagerdm
# [21:11:10] [modloading-worker-0/ERROR] [packmenu/]: Running on a dedicated server, disabling mod.
# [21:11:10] [modloading-worker-0/INFO] [PluginManager/]: Scanning classes for industrialforegoing
# [21:11:10] [modloading-worker-0/INFO] [PluginManager/]: Found FeaturePluginInstance for class CuriosPlugin for plugin curios
# [21:11:10] [modloading-worker-0/INFO] [PluginManager/]: Constructed class CuriosPlugin for plugin curios for mod industrialforegoing
# [21:11:10] [modloading-worker-0/INFO] [PluginManager/]: Executing phase CONSTRUCTION for plugin class CuriosPlugin
# [21:11:10] [modloading-worker-0/INFO] [PluginManager/]: Executing phase PRE_INIT for plugin class CuriosPlugin
# [21:11:10] [modloading-worker-0/INFO] [ir.IronFurnaces/]: Initializing Update Checker...
# [21:11:10] [ Iron Furnaces Update Checker/INFO] [ir.IronFurnaces/]: Starting Update Check...
# [21:11:10] [modloading-worker-0/INFO] [PluginManager/]: Executing phase INIT for plugin class CuriosPlugin
# [21:11:11] [modloading-worker-0/INFO] [PluginManager/]: Executing phase POST_INIT for plugin class CuriosPlugin
# [21:11:11] [modloading-worker-0/INFO] [ne.bd.li.ne.NetChannel/]: Initialized network channel 'multiblock' for mod 'bdlib'
# [21:11:11] [modloading-worker-0/INFO] [ne.bd.li.ne.NetChannel/]: Initialized network channel 'misc' for mod 'bdlib'
# [21:11:11] [modloading-worker-0/INFO] [ne.bd.li.BdLib$/]: Initialized multiblock manager for advgenerators
# [21:11:11] [modloading-worker-0/INFO] [ne.bd.li.ne.NetChannel/]: Initialized network channel 'generators' for mod 'advgenerators'
# [21:11:11] [modloading-worker-0/INFO] [se.go.ch.re.re.AbstractRegistrate/]: Detected new forge version, registering events reflectively.
# [21:11:11] [ Iron Furnaces Update Checker/INFO] [ir.IronFurnaces/]: Update Check done!
# [21:11:11] [ Iron Furnaces Update Checker/INFO] [ir.IronFurnaces/]: Iron Furnaces is up to date!
# [21:11:12] [modloading-worker-0/WARN] [ne.bl.mo.ba.fo.co.ForgeBalmConfig/]: Config field without expected type, will not validate list content (merchantNames in net.blay09.mods.farmingforblockheads.FarmingForBlockheadsConfigData)
# [Mouse Tweaks] Disabled because not running on the client.
# [21:11:14] [modloading-worker-0/INFO] [pneumaticcraft/]: Thirdparty integration activated for [theoneprobe,cofh_core,immersiveengineering,computercraft,jei,botania,mekanism,curios,patchouli,create]
# TagKey[minecraft:item / forge:tools]
# [21:11:14] [modloading-worker-0/INFO] [th.ko.te.KotlinForForge/]: Kotlin For Forge Enabled!
# [21:11:14] [modloading-worker-0/INFO] [showcaseitem/]: Loading config: /workspaces/codespaces-jupyter/Minecraft-server/config/showcaseitem-common.toml
# [21:11:14] [modloading-worker-0/INFO] [showcaseitem/]: Built config: /workspaces/codespaces-jupyter/Minecraft-server/config/showcaseitem-common.toml
# [21:11:14] [modloading-worker-0/INFO] [showcaseitem/]: Loaded config: /workspaces/codespaces-jupyter/Minecraft-server/config/showcaseitem-common.toml
# [21:11:15] [modloading-worker-0/INFO] [Advanced Peripherals/]: AdvancedPeripherals says hello!
# [21:11:15] [modloading-worker-0/WARN] [Advanced Peripherals/]: Successfully loaded integration for botania
# [21:11:15] [modloading-worker-0/WARN] [Advanced Peripherals/]: Successfully loaded integration for create
# [21:11:15] [modloading-worker-0/WARN] [Advanced Peripherals/]: Successfully loaded integration for mekanism
# [21:11:15] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [21:11:15] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [21:11:15] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [21:11:15] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [21:11:15] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [21:11:15] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [21:11:15] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 40.2.17, for MC 1.18.2 with MCP 20220404.173914
# [21:11:15] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v40.2.17 Initialized
# [21:11:17] [modloading-worker-0/INFO] [ne.pe.ex.ExMachinis/]: Registering mod: exmachinis
# [21:11:18] [modloading-worker-0/INFO] [twilightforest/]: Loaded compatibility for mod Tinkers Construct.
# [21:11:19] [modloading-worker-0/INFO] [twilightforest/]: Skipped compatibility for mod undergarden.
# [21:11:19] [modloading-worker-0/INFO] [twilightforest/]: Loaded compatibility for mod Immersive Engineering.
# [21:11:19] [modloading-worker-0/INFO] [twilightforest/]: Loaded compatibility for mod Curios.
# [21:11:19] [modloading-worker-0/INFO] [de.wu.sq.SquatGrow/]: Config loading
# [21:11:19] [modloading-worker-0/INFO] [de.wu.sq.SquatGrow/]: Tags: []
# [21:11:19] [modloading-worker-0/INFO] [de.wu.sq.SquatGrow/]: Wildcards: []
# [21:11:19] [modloading-worker-0/INFO] [co.tt.re.AbstractRegistrate/]: Detected new forge version, registering events reflectively.
# [21:11:20] [modloading-worker-0/INFO] [co.tt.re.AbstractRegistrate/]: Detected new forge version, registering events reflectively.
# [21:11:20] [modloading-worker-0/ERROR] [toastcontrol/]: Running on a dedicated server, disabling mod.
# [21:11:20] [modloading-worker-0/INFO] [KubeJS/]: Looking for KubeJS plugins...
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source kubejs
# [21:11:21] [modloading-worker-0/ERROR] [KubeJS/]: Failed to load plugin dev.latvian.mods.kubejs.integration.forge.gamestages.GameStagesIntegration from source kubejs: java.lang.NoClassDefFoundError: net/darkhax/gamestages/event/GameStageEvent
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source lazierae2
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source kubejs_thermal
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source ftbic
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source ftbquests
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source kubejs_create
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source kubejs_immersive_engineering
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source exnihilosequentia
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source kubejs_mekanism
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source ponderjs
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source ftbchunks
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Found plugin source modonomicon
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Done in 201.5 ms
# [21:11:21] [modloading-worker-0/INFO] [KubeJS/]: Loaded common.properties
# [21:11:21] [modloading-worker-0/INFO] [Rhino Script Remapper/]: Loading Rhino Minecraft remapper...
# [21:11:21] [modloading-worker-0/INFO] [de.la.mo.rh.mo.ut.RhinoProperties/]: Rhino properties loaded.
# [21:11:21] [modloading-worker-0/INFO] [Rhino Script Remapper/]: Loading mappings for 1.18.2
# Loading schematic: bloodmagic:t_corridor
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@1f50b48a
# Loading schematic: bloodmagic:four_way_corridor_loot
# [21:11:22] [modloading-worker-0/INFO] [Mystical Agriculture/]: Registered plugin: com.blakebr0.mysticalagriculture.lib.ModCorePlugin
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@25838ce0
# Loading schematic: bloodmagic:four_way_corridor
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@3c1f3bac
# Loading schematic: bloodmagic:standard/ore_hold_1
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@22a2a4f9
# Loading schematic: bloodmagic:straight_corridor
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@4ad047ee
# Loading schematic: bloodmagic:overlapped_corridor
# [21:11:22] [modloading-worker-0/INFO] [Rhino Script Remapper/]: Done in 0.410 s
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@57b82666
# Loading schematic: bloodmagic:spiral_staircase
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@5db46120
# Loading schematic: bloodmagic:standard/water_way
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@3c56fc9f
# Loading schematic: bloodmagic:standard/mine_entrance
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@4e403697
# Loading schematic: bloodmagic:mines/mine_key
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@57b28c1e
# Loading schematic: bloodmagic:mines/pit
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@56807afa
# Loading schematic: bloodmagic:mines/corner_zombie_trap
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@68b96c3e
# Loading schematic: bloodmagic:mines/split_road
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@225c4781
# Loading schematic: bloodmagic:mines/station
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@5d5042cc
# Loading schematic: bloodmagic:mines/downward_tunnel
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@30046c51
# Loading schematic: bloodmagic:mines/junction_station
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@786b3ca5
# Loading schematic: bloodmagic:mines/downward_shaft
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@2af79f8b
# Loading schematic: bloodmagic:mines/nature_crossroad
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@70d5b64c
# Loading schematic: bloodmagic:mines/wolf_den
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@3ee922e1
# Loading schematic: bloodmagic:mines/ore_cavern
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@2f33a30d
# Loading schematic: bloodmagic:mines/straight_corridor
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@133a5665
# Loading schematic: bloodmagic:mines/bent_corridor
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@105305c4
# Loading schematic: bloodmagic:mines/fourway_corridor
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@58595159
# Loading schematic: bloodmagic:mini_dungeon/library
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@24bae291
# Loading schematic: bloodmagic:mini_dungeon/armoury
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@2280dad0
# Loading schematic: bloodmagic:mini_dungeon/farm
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@28822476
# Loading schematic: bloodmagic:mini_dungeon/portal_nether
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@53829438
# Loading schematic: bloodmagic:mini_dungeon/crypt
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@6dc311da
# Loading schematic: bloodmagic:standard/challenge_tower
# [21:11:22] [modloading-worker-0/INFO] [Mystical Agriculture/]: Registered plugin: com.blakebr0.mysticalcustomization.lib.ModCorePlugin
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@31514edc
# Loading schematic: bloodmagic:standard/big_library
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@3e23f754
# Loading schematic: bloodmagic:standard/small_crane
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@67d7ce8e
# Loading schematic: bloodmagic:standard/small_library
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@6b919202
# Loading schematic: bloodmagic:standard/small_smithy
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@38e53071
# Loading schematic: bloodmagic:standard/tall_spiral
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@706aa17f
# Loading schematic: bloodmagic:standard/small_arena
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@345e1fa5
# Loading schematic: bloodmagic:standard/antechamber
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@64a9923d
# Loading schematic: bloodmagic:standard/destroyed_end_portal
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@7b5662a2
# Loading schematic: bloodmagic:standard/four_way_corridor_loot
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@fc2b11
# Loading schematic: bloodmagic:t3_entrance
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@62eeba02
# Loading schematic: bloodmagic:standard_entrance
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@26709575
# Loading schematic: bloodmagic:default_deadend
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@4ba856de
# Loading schematic: bloodmagic:mines/deadend
# Resulting dungeon: wayoftime.bloodmagic.structures.DungeonRoom@647e174e
# # schematics: 42
# [21:11:22] [modloading-worker-0/INFO] [Mystical Agriculture/]: Registered plugin: com.blakebr0.mysticalagradditions.lib.ModCorePlugin
# [21:11:22] [modloading-worker-0/WARN] [ne.bl.mo.ba.fo.co.ForgeBalmConfig/]: Config field without expected type, will not validate list content (compressBlacklist in net.blay09.mods.craftingtweaks.config.CraftingTweaksConfigData$Common)
# [21:11:22] [modloading-worker-0/WARN] [ne.bl.mo.ba.fo.co.ForgeBalmConfig/]: Config field without expected type, will not validate list content (disabledAddons in net.blay09.mods.craftingtweaks.config.CraftingTweaksConfigData$Client)
# [21:11:22] [modloading-worker-0/INFO] [PluginManager/]: Scanning classes for titanium
# [21:11:22] [modloading-worker-0/INFO] [KubeJS Startup/]: Loaded script startup_scripts:customMekanism.js in 0.217 s
# [21:11:22] [modloading-worker-0/INFO] [KubeJS Startup/]: Hello, World! (You will only see this line once in console, during startup)
# [21:11:22] [modloading-worker-0/INFO] [KubeJS Startup/]: Loaded script startup_scripts:script.js in 0.017 s
# [21:11:22] [modloading-worker-0/INFO] [KubeJS Startup/]: Loaded script startup_scripts:custom_stuff.js in 0.001 s
# [21:11:22] [modloading-worker-0/INFO] [KubeJS Startup/]: Loaded script startup_scripts:worldgen.js in 0.002 s
# [21:11:22] [modloading-worker-0/INFO] [KubeJS Startup/]: Loaded 4/4 KubeJS startup scripts in 1.401 s
# [21:11:23] [modloading-worker-0/WARN] [KubeJS Startup/]: Class filter is disabled!
# [21:11:23] [modloading-worker-0/INFO] [ne.pe.py.Pylons/]: Registering mod: pylons
# [21:11:23] [modloading-worker-0/INFO] [ne.pe.py.Pylons/]: Registered 1 network packets
# [21:11:23] [modloading-worker-0/INFO] [wi.en.ModEngineersDecor/]: Engineer's Decor GIT id #837b867.
# [21:11:23] [modloading-worker-0/INFO] [PluginManager/]: Scanning classes for functionalstorage
# [21:11:23] [modloading-worker-0/INFO] [PluginManager/]: Found FeaturePluginInstance for class TOPPlugin for plugin theoneprobe
# [21:11:23] [modloading-worker-0/INFO] [PluginManager/]: Constructed class TOPPlugin for plugin theoneprobe for mod functionalstorage
# [21:11:23] [modloading-worker-0/INFO] [PluginManager/]: Executing phase CONSTRUCTION for plugin class TOPPlugin
# [21:11:23] [modloading-worker-0/INFO] [PluginManager/]: Executing phase PRE_INIT for plugin class TOPPlugin
# [21:11:23] [modloading-worker-0/INFO] [PluginManager/]: Executing phase INIT for plugin class TOPPlugin
# [21:11:23] [modloading-worker-0/INFO] [PluginManager/]: Executing phase POST_INIT for plugin class TOPPlugin
# [21:11:24] [modloading-worker-0/INFO] [co.tt.re.AbstractRegistrate/]: Detected new forge version, registering events reflectively.
# [21:11:59] [main/INFO] [wi.en.ModEngineersDecor/]: Immersive Engineering also installed ...
# [21:12:01] [main/INFO] [co.gi.kl.oc.Occultism/]: Registered BlockItems
# [21:12:01] [main/INFO] [co.gi.kl.oc.Occultism/]: Registered compostable Items
# Attempting to load Anointment: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/anointment/melee_damage.json, path: /data/bloodmagic/anointment/melee_damage.json
# Attempting to load Anointment: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/anointment/holy_water.json, path: /data/bloodmagic/anointment/holy_water.json
# Attempting to load Anointment: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/anointment/hidden_knowledge.json, path: /data/bloodmagic/anointment/hidden_knowledge.json
# Attempting to load Anointment: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/anointment/quick_draw.json, path: /data/bloodmagic/anointment/quick_draw.json
# Attempting to load Anointment: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/anointment/bow_power.json, path: /data/bloodmagic/anointment/bow_power.json
# Attempting to load Anointment: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/anointment/bow_velocity.json, path: /data/bloodmagic/anointment/bow_velocity.json
# Attempting to load Anointment: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/anointment/repairing.json, path: /data/bloodmagic/anointment/repairing.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/arrow_protect.json, path: /data/bloodmagic/living_armor/arrow_protect.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/fall_protect.json, path: /data/bloodmagic/living_armor/fall_protect.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/physical_protect.json, path: /data/bloodmagic/living_armor/physical_protect.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/jump.json, path: /data/bloodmagic/living_armor/jump.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/health.json, path: /data/bloodmagic/living_armor/health.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/experienced.json, path: /data/bloodmagic/living_armor/experienced.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/sprint_attack.json, path: /data/bloodmagic/living_armor/sprint_attack.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/self_sacrifice.json, path: /data/bloodmagic/living_armor/self_sacrifice.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/speed.json, path: /data/bloodmagic/living_armor/speed.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/poison_resist.json, path: /data/bloodmagic/living_armor/poison_resist.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/fire_resist.json, path: /data/bloodmagic/living_armor/fire_resist.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/digging.json, path: /data/bloodmagic/living_armor/digging.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/knockback_resist.json, path: /data/bloodmagic/living_armor/knockback_resist.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/diamond_protect.json, path: /data/bloodmagic/living_armor/diamond_protect.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/elytra.json, path: /data/bloodmagic/living_armor/elytra.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/curios_socket.json, path: /data/bloodmagic/living_armor/curios_socket.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/melee_damage.json, path: /data/bloodmagic/living_armor/melee_damage.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/repair.json, path: /data/bloodmagic/living_armor/repair.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/quenched.json, path: /data/bloodmagic/living_armor/downgrade/quenched.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/storm_trooper.json, path: /data/bloodmagic/living_armor/downgrade/storm_trooper.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/battle_hungry.json, path: /data/bloodmagic/living_armor/downgrade/battle_hungry.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/melee_decrease.json, path: /data/bloodmagic/living_armor/downgrade/melee_decrease.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/dig_slowdown.json, path: /data/bloodmagic/living_armor/downgrade/dig_slowdown.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/slow_heal.json, path: /data/bloodmagic/living_armor/downgrade/slow_heal.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/crippled_arm.json, path: /data/bloodmagic/living_armor/downgrade/crippled_arm.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/swim_decrease.json, path: /data/bloodmagic/living_armor/downgrade/swim_decrease.json
# Attempting to load Living Armour Upgrade: union:/workspaces/codespaces-jupyter/Minecraft-server/mods/BloodMagic-1.18.2-3.2.6-41.jar%2366!/data/bloodmagic/living_armor/downgrade/speed_decrease.json, path: /data/bloodmagic/living_armor/downgrade/speed_decrease.json
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:dirty_aluminum] has been registered twice for the same name alltheores:dirty_aluminum.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:dirty_nickel] has been registered twice for the same name alltheores:dirty_nickel.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:dirty_platinum] has been registered twice for the same name alltheores:dirty_platinum.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:dirty_silver] has been registered twice for the same name alltheores:dirty_silver.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:dirty_tin] has been registered twice for the same name alltheores:dirty_tin.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:dirty_zinc] has been registered twice for the same name alltheores:dirty_zinc.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:clean_aluminum] has been registered twice for the same name alltheores:clean_aluminum.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:clean_nickel] has been registered twice for the same name alltheores:clean_nickel.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:clean_platinum] has been registered twice for the same name alltheores:clean_platinum.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:clean_silver] has been registered twice for the same name alltheores:clean_silver.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:clean_tin] has been registered twice for the same name alltheores:clean_tin.
# [21:12:04] [main/WARN] [ne.mi.re.ForgeRegistry/REGISTRIES]: Registry mekanism:slurry: The object [Slurry: alltheores:clean_zinc] has been registered twice for the same name alltheores:clean_zinc.
# [21:12:05] [main/INFO] [wa.bl.BloodMagic/]: Attempting to register Tile Entities
# [21:12:08] [main/INFO] [alltheores/]: AllTheOres: loading config
# [21:12:08] [Thread-0/INFO] [alltheores/]: AllTheOres: loading config
# [21:12:08] [Thread-0/INFO] [alltheores/]: AllTheOres: loading config
# [21:12:08] [main/INFO] [PluginManager/]: Executing phase CONFIG_LOAD for plugin class CuriosPlugin
# [21:12:08] [main/INFO] [PluginManager/]: Executing phase CONFIG_LOAD for plugin class CuriosPlugin
# [21:12:08] [main/INFO] [PluginManager/]: Executing phase CONFIG_LOAD for plugin class CuriosPlugin
# [21:12:08] [main/INFO] [PluginManager/]: Executing phase CONFIG_LOAD for plugin class CuriosPlugin
# [21:12:08] [Thread-0/INFO] [PluginManager/]: Executing phase CONFIG_RELOAD for plugin class CuriosPlugin
# [21:12:08] [main/INFO] [PluginManager/]: Executing phase CONFIG_LOAD for plugin class CuriosPlugin
# [21:12:08] [Thread-0/INFO] [PluginManager/]: Executing phase CONFIG_RELOAD for plugin class CuriosPlugin
# [21:12:08] [Thread-0/FATAL] [mc.th.TheOneProbe/CORE]: theoneprobe config just got changed on the file system!
# [21:12:08] [Thread-0/FATAL] [mc.th.TheOneProbe/CORE]: theoneprobe config just got changed on the file system!
# [21:12:09] [main/INFO] [PluginManager/]: Executing phase CONFIG_LOAD for plugin class TOPPlugin
# [21:12:09] [main/INFO] [PluginManager/]: Executing phase CONFIG_LOAD for plugin class TOPPlugin
# [21:12:09] [Thread-0/INFO] [PluginManager/]: Executing phase CONFIG_RELOAD for plugin class TOPPlugin
# [21:12:09] [Thread-0/INFO] [wi.en.ModEngineersDecor/]: Config file changed engineersdecor-common.toml
# [21:12:09] [Thread-0/INFO] [PluginManager/]: Executing phase CONFIG_RELOAD for plugin class TOPPlugin
# [21:12:09] [modloading-worker-0/INFO] [integrateddynamics/]: Registered packet handler.
# [21:12:09] [modloading-worker-0/INFO] [PluginManager/]: Executing phase COMMON_SETUP for plugin class CuriosPlugin
# [21:12:09] [modloading-worker-0/INFO] [th.co.ConstructionWand/]: ConstructionWand says hello - may the odds be ever in your favor.
# [21:12:09] [modloading-worker-0/INFO] [th.co.ConstructionWand/]: Botania integration added
# [21:12:09] [modloading-worker-0/INFO] [Mekanism/]: Version 10.2.5 initializing...
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: PneumaticCraft: Repressurized is loading!
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: air_canister compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: reinforced_air_canister compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: vortex_cannon compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: pneumatic_wrench compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: manometer compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: logistics_configurator compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: amadron_tablet compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: minigun compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: camo_applicator compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: jackhammer compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: pneumatic_helmet compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: pneumatic_chestplate compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: pneumatic_leggings compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: pneumatic_boots compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: drone compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: logistics_drone compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: harvesting_drone compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: guard_drone compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [pneumaticcraft/]: Making item: collector_drone compatible with Holding enchantment.
# [21:12:09] [modloading-worker-0/INFO] [Mekanism/]: Fake player readout: UUID = 46e82cd0-d480-3d48-800a-77431ede078e, name = [Mekanism]
# [21:12:09] [modloading-worker-0/INFO] [Mekanism/]: Mod loaded.
# [21:12:09] [modloading-worker-0/INFO] [mythicbotany/]: Loading MythicBotany
# [21:12:09] [Immersive Engineering Contributors Thread/INFO] [immersiveengineering/]: Attempting to download special revolvers from GitHub
# [21:12:09] [modloading-worker-0/INFO] [integrateddynamicscompat/]: Registered packet handler.
# [21:12:09] [modloading-worker-0/INFO] [co.da.se.ServerConfigUpdater/]: Attempting to delete 1 files/folders defined in config
# [21:12:09] [modloading-worker-0/INFO] [integrateddynamics/]: Registered packet handler.
# [21:12:10] [modloading-worker-0/INFO] [co.co.Connectivity/]: Connectivity initialized
# [21:12:10] [modloading-worker-0/INFO] [co.gi.kl.oc.Occultism/]: Common setup complete.
# [21:12:10] [modloading-worker-0/INFO] [Mekanism/]: Loaded 'Mekanism Generators' module.
# [21:12:10] [modloading-worker-0/WARN] [patchouli/]: Book botania:lexicon is a resource-pack-based book. Extension books are unnecessary for resource-pack-based books. You should simply create a resource pack with the extra content you want to add or override.
# [21:12:10] [modloading-worker-0/INFO] [Mekanism/]: Loaded 'Mekanism: Tools' module.
# [21:12:10] [modloading-worker-0/INFO] [cy.jd.pr.ProductiveBees/]: Adding modded beehives to vanilla beehive POI
# [21:12:10] [modloading-worker-0/INFO] [mcjtylib/]: RFTools Storage Detected XNet: enabling support
# [21:12:10] [modloading-worker-0/WARN] [FluxNetworks/]: Use FML network channel (low performance)
# [21:12:10] [modloading-worker-0/INFO] [PluginManager/]: Executing phase COMMON_SETUP for plugin class TOPPlugin
# [21:12:10] [modloading-worker-0/INFO] [co.kl.mo.Modonomicon/]: Common setup complete.
# [21:12:12] [modloading-worker-0/INFO] [co.gi.kl.oc.Occultism/]: Dedicated server setup complete.
# [21:12:12] [modloading-worker-0/INFO] [co.kl.mo.Modonomicon/]: Dedicated server setup complete.
# [21:12:12] [modloading-worker-0/INFO] [pneumaticcraft/]: Sending IMC messages.
# [21:12:12] [modloading-worker-0/INFO] [pneumaticcraft/]: Enabled support for The One Probe
# [21:12:12] [modloading-worker-0/INFO] [ne.bl.mo.cr.IMCHandler/]: slabmachines has registered com.mrbysco.slabmachines.container.SlabBenchContainer for CraftingTweaks
# [21:12:12] [modloading-worker-0/INFO] [mcjtylib/]: Enabled support for The One Probe
# [21:12:12] [modloading-worker-0/INFO] [mcjtylib/]: Enabled support for The One Probe
# [21:12:12] [modloading-worker-0/INFO] [tombstone/]: Integration TOP
# [21:12:12] [modloading-worker-0/INFO] [no.ex.co.co.to.Co.GetTheOneProbe/]: [Ex Nihilo: Sequentia]: Enabled support for The One Probe
# [21:12:12] [modloading-worker-0/INFO] [ne.xa.to.Torchmaster/]: Applying mega torch entity block list overrides...
# [21:12:12] [modloading-worker-0/INFO] [ne.xa.to.Torchmaster/]: Applying dread lamp entity block list overrides...
# [21:12:12] [modloading-worker-0/INFO] [AttributeFix/]: Loaded values for 35 compatible attributes.
# [21:12:12] [modloading-worker-0/INFO] [AttributeFix/]: Loaded 35 values from config.
# [21:12:12] [modloading-worker-0/INFO] [AttributeFix/]: Saving config file. 35 entries.
# [21:12:12] [modloading-worker-0/INFO] [AttributeFix/]: Applying changes for 35 attributes.
# Create Crafts & Additions Initialized!
# [21:12:12] [modloading-worker-0/ERROR] [bloodmagic/]: MysticalAgriculture integration cancelled: unable to find a class: com.blakebr0.mysticalagriculture.api.crop.ICrop
# [21:12:46] [main/WARN] [minecraft/VanillaPackResources]: Assets URL 'union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23270!/assets/.mcassetsroot' uses unexpected schema
# [21:12:46] [main/WARN] [minecraft/VanillaPackResources]: Assets URL 'union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23270!/data/.mcassetsroot' uses unexpected schema
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:tags.js in 0.013 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:constants.js in 0.01 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:unify.js in 0.031 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ex_nihilo/ex_nihilo.js in 0.008 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:craftingenhancements.js in 0.002 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:sawmillCompat.js in 0.031 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/projecte/worldTransmute.js in 0.011 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/projecte/projectE.js in 0.002 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/functionalstorge/compacting.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ae/ae.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/misc/music_discs.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/misc/tweaks.js in 0.002 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/cobblefordays/cobblegen.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/mekanism/mekanism.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/mekanism/cobalt.js in 0.002 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/reliquary/removals.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/mysticalagriculture/ma_crops.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/mysticalagriculture/mysticalagriculture.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/mysticalagriculture/ma_crafting.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/occultism/iesnium.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/apotheosis/removals.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/notenoughwands/removals.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/rftools/rftools.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/spirit/transmutation.js in 0.01 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ATM/custom_recipes.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ATM/allthemodium.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ATM/atm_star_creative.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ATM/atm_shard.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ATM/atm_star.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ftbic/ftbic.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/ex_nihilo/ex_nihilo_pebbles.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/thermal/rock_gen.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/exmachinis/pebble.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/exmachinis/raw_ore.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/exmachinis/orepiece.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/buildinggadgets/buildinggadgets.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/computercraft/computercraft.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:mod_specific/twilightforest/twilight.js in 0.0 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:stonecutting.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded script server_scripts:xpFluids.js in 0.001 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Loaded 40/40 KubeJS server scripts in 0.188 s
# [21:12:46] [main/INFO] [KubeJS Server/]: Scripts loaded
# ...
# [21:44:15] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Survival Mode]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [21:56:00] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: Juanfri031 moved wrongly!
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [22:15:59] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2291ms or 45 ticks behind
# [22:18:05] [Server thread/INFO] [ne.mi.co.AdvancementLoadFix/]: Using new advancement loading for net.minecraft.server.PlayerAdvancements@5c0c043
# [22:18:05] [Server thread/INFO] [minecraft/PlayerList]: Lurken[/[0:0:0:0:0:0:0:1%0]:47378] logged in with entity id 77541 at (5.5, 66.2, 3.5)
# [22:18:05] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken joined the game
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [22:21:00] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Home sweet home]
# [22:22:08] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2442ms or 48 ticks behind
# [22:22:11] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: Juanfri031 moved too quickly! 9.43755236047582,0.6005372011627372,-3.3562899913058573
# [22:23:43] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Creative Mode]
# [22:23:44] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Spectator Mode]
# [22:23:48] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Creative Mode]
# [22:24:27] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Spectator Mode]
# [22:24:29] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Creative Mode]
# [22:24:32] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Spectator Mode]
# [22:24:41] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Survival Mode]
# [22:25:03] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Home sweet home]
# [22:25:39] [Server thread/INFO] [minecraft/DedicatedServer]: [Lurken: Successfully joined team Downs.]
# [22:26:32] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has made the advancement [A Stunning Fixation]
# [22:26:32] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has completed the challenge [He Wasn't So Strong]
# [22:26:32] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has made the advancement [Epic!]
# [22:26:32] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has made the advancement [It Certainly Seems Rare...]
# [22:26:32] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has made the advancement [How'd You Get This?]
# [22:26:33] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has made the advancement [Cover Me with Diamonds]
# [22:26:33] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has made the advancement [Suit Up]
# [22:26:33] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has reached the goal [Titan-Forged]
# [22:26:34] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has made the advancement [Not Quite Common]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [22:32:52] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken has made the advancement [Monster Hunter]
# [22:36:20] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: Juanfri031 moved too quickly! -8.707271430565015,-4.60623627942438,-3.399569510622314
# [22:36:20] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2299ms or 45 ticks behind
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [22:40:12] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: Lurken lost connection: Disconnected
# [22:40:12] [Server thread/INFO] [minecraft/DedicatedServer]: Lurken left the game
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [22:51:07] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Spectator Mode]
# [22:51:14] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Creative Mode]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [23:15:43] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Spectator Mode]
# [23:15:46] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Creative Mode]
# [23:15:50] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Survival Mode]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [00:00:13] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Creative Mode]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [00:00:19] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Set own game mode to Survival Mode]
# [00:07:28] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Saved the game]
# [00:07:34] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Saved the game]
# [00:07:36] [Server thread/INFO] [minecraft/DedicatedServer]: [Juanfri031: Stopping the server]
# [00:07:36] [Server thread/INFO] [minecraft/MinecraftServer]: Stopping server
# [00:07:36] [Server thread/INFO] [minecraft/MinecraftServer]: Saving players
# [00:07:36] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: Juanfri031 lost connection: Server closed
# [00:07:36] [Server thread/INFO] [minecraft/DedicatedServer]: Juanfri031 left the game
# [00:07:36] [Server thread/INFO] [minecraft/MinecraftServer]: Saving worlds
# [00:07:36] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/minecraft:overworld
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/minecraft:the_nether
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/allthemodium:the_other
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/bloodmagic:dungeon
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/minecraft:the_end
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/compactmachines:compact_world
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/mythicbotany:alfheim
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/allthemodium:mining
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/twilightforest:twilight_forest
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: Saving chunks for level 'ServerLevel[world]'/ae2:spatial_storage
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (world): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (DIM-1): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (the_other): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (dungeon): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (DIM1): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (compact_world): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (alfheim): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (mining): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (twilight_forest): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage (spatial_storage): All chunks are saved
# [00:07:50] [Server thread/INFO] [minecraft/MinecraftServer]: ThreadedAnvilChunkStorage: All dimensions are saved
# [00:07:50] [Server thread/INFO] [FTB Chunks/]: Shutting down map thread
# >
